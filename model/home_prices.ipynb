# %%
import math

# %%
import pandas as pd

# %%
df = pd.read_csv('germany_houses.csv')
df
# Out:
#        Unnamed: 0      Price               Type  Living_space     Lot  \
# 0               0   498000.0  Multiple dwelling        106.00   229.0
# 1               1   495000.0  Mid-terrace house        140.93   517.0
# 2               2   749000.0          Farmhouse        162.89    82.0
# 3               3   259000.0          Farmhouse        140.00   814.0
# 4               4   469000.0  Multiple dwelling        115.00   244.0
# ...           ...        ...                ...           ...     ...
# 10547       10547  1495000.0   Special property        167.00   683.0
# 10548       10548   449000.0  Mid-terrace house        222.00  4000.0
# 10549       10549   678000.0  Mid-terrace house        142.00   377.0
# 10550       10550   419900.0  Mid-terrace house        120.83   501.0
# 10551       10551   699000.0  Multiple dwelling        145.00   357.0
#
#        Usable_area     Free_of_Relation  Rooms  Bedrooms  Bathrooms  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Type', 'Living_space', 'Lot', 'Usable_area',
#        'Free_of_Relation', 'Rooms', 'Bedrooms', 'Bathrooms', 'Floors',
#        'Year_built', 'Furnishing_quality', 'Year_renovated', 'Condition',
#        'Heating', 'Energy_source', 'Energy_certificate',
#        'Energy_certificate_type', 'Energy_consumption',
#        'Energy_efficiency_class', 'State', 'City', 'Place', 'Garages',
#        'Garagetype'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0         Price  Living_space            Lot  Usable_area  \
# count  10552.000000  1.055200e+04  10552.000000   10552.000000  5568.000000
# mean    5275.500000  5.566851e+05    216.721008    1491.659004   134.300424
# std     3046.244354  6.087410e+05    172.421321    8582.361675   188.814089
# min        0.000000  0.000000e+00      0.000000       0.000000     0.000000
# 25%     2637.750000  2.500000e+05    130.000000     370.000000    48.000000
# 50%     5275.500000  4.052150e+05    176.775000     656.500000    80.000000
# 75%     7913.250000  6.550000e+05    250.000000    1047.000000   150.250000
# max    10551.000000  1.300000e+07   5600.000000  547087.000000  4034.000000
#
#               Rooms     Bedrooms    Bathrooms       Floors   Year_built  \
# count  10552.000000  6878.000000  8751.000000  7888.000000  9858.000000
# mean       7.388978     4.169817     2.308993     2.283976  1958.821465
# ...

# %%
df.shape
# Out:
# (10552, 26)

# %%
df.drop(['Unnamed: 0','Energy_certificate_type','Garagetype'],axis='columns',inplace=True)
df.drop(['Free_of_Relation','Heating','Condition'],axis='columns',inplace=True)
df.drop(['Living_space','Usable_area','Year_renovated','Year_built','Energy_source','Energy_certificate','Energy_efficiency_class','City','Place'],axis='columns',inplace=True)

# %%
df.columns
# Out:
# Index(['Price', 'Type', 'Lot', 'Rooms', 'Bedrooms', 'Bathrooms', 'Floors',
#        'Furnishing_quality', 'Energy_consumption', 'State', 'Garages'],
#       dtype='object')

# %%
df.shape
# Out:
# (10552, 11)

# %%
df.isna()
# Out:
#        Price   Type    Lot  Rooms  Bedrooms  Bathrooms  Floors  \
# 0      False  False  False  False     False      False   False
# 1      False  False  False  False     False      False    True
# 2      False  False  False  False     False      False   False
# 3      False  False  False  False      True      False   False
# 4      False  False  False  False     False      False    True
# ...      ...    ...    ...    ...       ...        ...     ...
# 10547  False  False  False  False     False      False    True
# 10548  False  False  False  False     False      False   False
# 10549  False  False  False  False     False       True    True
# 10550  False  False  False  False      True      False   False
# 10551  False  False  False  False     False      False   False
#
#        Furnishing_quality  Energy_consumption  State  Garages
# 0                   False                True  False    False
# 1                   False                True  False    False
# ...

# %%
df.dtypes
# Out:
# Price                 float64
# Type                   object
# Lot                   float64
# Rooms                 float64
# Bedrooms              float64
# Bathrooms             float64
# Floors                float64
# Furnishing_quality     object
# Energy_consumption    float64
# State                  object
# Garages               float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Price                    0
# Type                   402
# Lot                      0
# Rooms                    0
# Bedrooms              3674
# Bathrooms             1801
# Floors                2664
# Furnishing_quality    2726
# Energy_consumption    8119
# State                    1
# Garages               1960
# dtype: int64

# %%
import math

# %%
df['Bedrooms'] = df['Bedrooms'].fillna(df['Bedrooms'].mean())

# %%
df['Bathrooms'] = df['Bathrooms'].fillna(df['Bathrooms'].mean())

# %%
df['Floors'] = df['Floors'].fillna(df['Floors'].mean())

# %%
df['Energy_consumption'] = df['Energy_consumption'].fillna(df['Energy_consumption'].mean())

# %%
df['Garages'] = df['Garages'].fillna(df['Garages'].mean())

# %%
df.isna().sum()
# Out:
# Price                    0
# Type                   402
# Lot                      0
# Rooms                    0
# Bedrooms                 0
# Bathrooms                0
# Floors                   0
# Furnishing_quality    2726
# Energy_consumption       0
# State                    1
# Garages                  0
# dtype: int64

# %%
df
# Out:
#            Price               Type     Lot  Rooms  Bedrooms  Bathrooms  \
# 0       498000.0  Multiple dwelling   229.0    5.5  3.000000   1.000000
# 1       495000.0  Mid-terrace house   517.0    6.0  3.000000   2.000000
# 2       749000.0          Farmhouse    82.0    5.0  3.000000   2.000000
# 3       259000.0          Farmhouse   814.0    4.0  4.169817   2.000000
# 4       469000.0  Multiple dwelling   244.0    4.5  2.000000   1.000000
# ...          ...                ...     ...    ...       ...        ...
# 10547  1495000.0   Special property   683.0    6.5  4.000000   3.000000
# 10548   449000.0  Mid-terrace house  4000.0    6.0  5.000000   3.000000
# 10549   678000.0  Mid-terrace house   377.0    4.0  3.000000   2.308993
# 10550   419900.0  Mid-terrace house   501.0    5.0  4.169817   1.000000
# 10551   699000.0  Multiple dwelling   357.0    5.5  4.000000   1.000000
#
#          Floors Furnishing_quality  Energy_consumption              State  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7517, 11)

# %%
df.isna().sum()
# Out:
# Price                 0
# Type                  0
# Lot                   0
# Rooms                 0
# Bedrooms              0
# Bathrooms             0
# Floors                0
# Furnishing_quality    0
# Energy_consumption    0
# State                 0
# Garages               0
# dtype: int64

# %%
df.Type.unique()
# Out:
# array(['Multiple dwelling', 'Mid-terrace house', 'Farmhouse', 'Duplex',
#        'Single dwelling', 'Special property', 'Bungalow', 'Villa',
#        'Corner house', 'Residential property', 'Castle'], dtype=object)

# %%
df.Bathrooms = df.Bathrooms.astype(int)
df.Bedrooms = df.Bedrooms.astype(int)
df.Floors = df.Floors.astype(int)
df.Energy_consumption = df.Energy_consumption.astype(int)
df.Garages = df.Garages.astype(int)
df.Rooms = df.Bathrooms.astype(int)
df
# Out:
#            Price               Type     Lot  Rooms  Bedrooms  Bathrooms  \
# 0       498000.0  Multiple dwelling   229.0      1         3          1
# 1       495000.0  Mid-terrace house   517.0      2         3          2
# 3       259000.0          Farmhouse   814.0      2         4          2
# 4       469000.0  Multiple dwelling   244.0      1         2          1
# 5      1400000.0  Mid-terrace house   860.0      2         4          2
# ...          ...                ...     ...    ...       ...        ...
# 10541   820000.0  Mid-terrace house  1946.0      2         4          2
# 10542   399000.0          Farmhouse   160.0      1         4          1
# 10543   565000.0  Mid-terrace house   660.0      2         3          2
# 10549   678000.0  Mid-terrace house   377.0      2         3          2
# 10550   419900.0  Mid-terrace house   501.0      1         4          1
#
#        Floors Furnishing_quality  Energy_consumption              State  \
# ...

# %%
df.Type.unique()
# Out:
# array(['Multiple dwelling', 'Mid-terrace house', 'Farmhouse', 'Duplex',
#        'Single dwelling', 'Special property', 'Bungalow', 'Villa',
#        'Corner house', 'Residential property', 'Castle'], dtype=object)

# %%
df.Furnishing_quality.unique()
# Out:
# array(['normal', 'basic', 'refined', 'luxus'], dtype=object)

# %%
df.State.unique()
# Out:
# array(['Baden-Württemberg', 'Rheinland-Pfalz', 'Hessen', 'Bayern',
#        'Berlin', 'Brandenburg', 'Bremen', 'Niedersachsen', 'Hamburg',
#        'Nordrhein-Westfalen', 'Mecklenburg-Vorpommern', 'Saarland',
#        'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen'],
#       dtype=object)

# %%
df['rooms'] = df.Bedrooms + df.Rooms
df.drop(['Bedrooms','Rooms','Energy_consumption'],axis='columns',inplace=True)
df
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
#       Furnishing_quality              State  Garages  rooms
# 0                 normal  Baden-Württemberg        2      4
# 1                  basic  Baden-Württemberg        7      5
# ...

# %%
lower_limit, upper_limit = df.Price.mean() -3*df.Price.std(), df.Price.mean() + 3*df.Price.std()

# %%
df[(df.Price>upper_limit) | (df.Price<lower_limit)]
# Out:
#            Price               Type      Lot  Bathrooms  Floors  \
# 6      3500000.0             Duplex   5300.0          4       2
# 27     2500000.0  Mid-terrace house    855.0          3       3
# 112    2490000.0              Villa   2247.0          2       4
# 218    3100000.0  Mid-terrace house    537.0          2       2
# 258    4722000.0             Duplex   1414.0         13       2
# ...          ...                ...      ...        ...     ...
# 10003  2790000.0             Duplex    554.0          2       2
# 10118  4095000.0  Mid-terrace house    700.0          3       2
# 10136  2450000.0    Single dwelling    736.0          3       3
# 10346  2500000.0  Mid-terrace house  54403.0          2       2
# 10379  5575000.0    Single dwelling    850.0          4       2
#
#       Furnishing_quality               State  Garages  rooms
# 6                  basic   Baden-Württemberg        7      8
# 27                 luxus   Baden-Württemberg        2      8
# ...

# %%
df1= df[(df.Price<upper_limit) & (df.Price>lower_limit)]

# %%
lower_limit, upper_limit = df1.Lot.mean() -3*df1.Lot.std(), df1.Lot.mean() + 3*df1.Lot.std()

# %%
df1[(df1.Lot>upper_limit) | (df1.Lot<lower_limit)]
# Out:
#            Price                  Type       Lot  Bathrooms  Floors  \
# 185    1498000.0          Corner house  547087.0          1       2
# 688     390000.0     Mid-terrace house   36715.0          2       1
# 1311   2150000.0          Corner house  101000.0          7       3
# 1431   1580000.0     Mid-terrace house   52000.0          2       2
# 1519    725000.0          Corner house   47332.0          2       2
# 1757   1150000.0     Mid-terrace house   40287.0          2       2
# 1826   1420000.0                Duplex  188000.0          2       3
# 1993   1890000.0     Mid-terrace house  143432.0          4       3
# 2235   1150000.0     Mid-terrace house   40287.0          2       2
# 2583    459000.0              Bungalow   38000.0          3       2
# 3160    279000.0  Residential property   63000.0          2       2
# 3189         0.0                Duplex   34997.0          2       2
# 3203    750000.0                Duplex   65648.0          2       2
# ...

# %%
df2= df1[(df1.Lot<upper_limit) & (df1.Lot>lower_limit)]
df2
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
#       Furnishing_quality              State  Garages  rooms
# 0                 normal  Baden-Württemberg        2      4
# 1                  basic  Baden-Württemberg        7      5
# ...

# %%
lower_limit, upper_limit = df2.Bathrooms.mean() -3*df2.Bathrooms.std(), df2.Bathrooms.mean() + 3*df2.Bathrooms.std()

# %%
df2[(df2.Bathrooms>upper_limit) | (df2.Bathrooms<lower_limit)]
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 235    1250000.0             Duplex  2665.0          9       4
# 342    1280000.0             Duplex   152.0         10       5
# 353    1950000.0             Duplex   816.0         10       4
# 420    1050000.0             Duplex   312.0          8       3
# 458     645000.0             Duplex   646.0          8       3
# ...          ...                ...     ...        ...     ...
# 9709     65000.0             Duplex   466.0          9       3
# 9840    850000.0             Duplex  1937.0          8       2
# 9993    729000.0             Duplex  2621.0         12       2
# 10088   169000.0  Multiple dwelling   323.0         22       2
# 10495   780000.0             Duplex   250.0         10       3
#
#       Furnishing_quality               State  Garages  rooms
# 235               normal   Baden-Württemberg        8     17
# 342               normal   Baden-Württemberg        2     14
# ...

# %%
df3= df2[(df2.Bathrooms<upper_limit) & (df2.Bathrooms>lower_limit)]
df3
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
#       Furnishing_quality              State  Garages  rooms
# 0                 normal  Baden-Württemberg        2      4
# 1                  basic  Baden-Württemberg        7      5
# ...

# %%
lower_limit, upper_limit = df3.Floors.mean() -3*df3.Floors.std(), df3.Floors.mean() + 3*df3.Floors.std()

# %%
df3[(df3.Floors>upper_limit) | (df3.Floors<lower_limit)]
# Out:
#            Price                  Type       Lot  Bathrooms  Floors  \
# 75      838000.0                Duplex   2314.00          4       5
# 168     826000.0                Duplex    564.00          3       0
# 380     398000.0              Bungalow     96.00          2       5
# 820    1450000.0                Duplex    227.27          4       5
# 1151    349000.0                Duplex    128.00          4       5
# 1298    890000.0              Bungalow    491.00          2       5
# 1326    749000.0                Duplex    860.00          2       0
# 1341    375000.0                Duplex   1469.00          2       0
# 1428    565000.0             Farmhouse    360.00          2       5
# 1460     59900.0     Mid-terrace house    888.00          1       0
# 1461    158900.0     Mid-terrace house    288.00          1       0
# 1465    450000.0                Duplex    850.00          6       0
# 1468    129500.0     Mid-terrace house    855.00          2       0
# ...

# %%
df4= df3[(df3.Floors<upper_limit) & (df3.Floors>lower_limit)]
df4
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
#       Furnishing_quality              State  Garages  rooms
# 0                 normal  Baden-Württemberg        2      4
# 1                  basic  Baden-Württemberg        7      5
# ...

# %%
lower_limit, upper_limit = df4.Garages.mean() -3*df4.Garages.std(), df4.Garages.mean() + 3*df4.Garages.std()

# %%
df4[(df4.Garages>upper_limit) | (df4.Garages<lower_limit)]
# Out:
#            Price               Type      Lot  Bathrooms  Floors  \
# 9      1900000.0             Duplex    933.0          2       3
# 34     1650000.0             Duplex    950.0          2       2
# 40      399000.0             Duplex   1725.0          3       3
# 104     890000.0             Duplex   2003.0          2       2
# 175    1690000.0           Bungalow   1000.0          2       3
# ...          ...                ...      ...        ...     ...
# 10324   950000.0             Duplex   2590.0          2       1
# 10378   311600.0           Bungalow  22613.0          2       1
# 10476   198000.0  Mid-terrace house    700.0          2       2
# 10510    85000.0             Duplex    770.0          2       2
# 10517   169000.0             Duplex   2560.0          3       3
#
#       Furnishing_quality               State  Garages  rooms
# 9                  basic   Baden-Württemberg       12      6
# 34                 basic   Baden-Württemberg       10      6
# ...

# %%
df5= df4[(df4.Garages<upper_limit) & (df4.Garages>lower_limit)]
df5
# Out:
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
#       Furnishing_quality              State  Garages  rooms
# 0                 normal  Baden-Württemberg        2      4
# 1                  basic  Baden-Württemberg        7      5
# ...

# %%
lower_limit, upper_limit = df5.rooms.mean() -3*df5.rooms.std(), df5.rooms.mean() + 3*df5.rooms.std()

# %%
df5[(df5.rooms>upper_limit) | (df5.rooms<lower_limit)]
# Out:
#            Price                  Type       Lot  Bathrooms  Floors  \
# 162    1290000.0                Duplex    743.00          5       2
# 170     740000.0                Duplex   1927.00          5       2
# 248    1475000.0                Duplex    479.00          4       3
# 294     649000.0                Duplex   1678.00          5       4
# 377    1290000.0                 Villa    365.00          4       4
# ...          ...                   ...       ...        ...     ...
# 9789     37300.0                Duplex    980.00          1       3
# 10184   798000.0     Mid-terrace house    865.00          4       3
# 10311   520000.0     Mid-terrace house   2315.01          1       1
# 10321   665000.0  Residential property  10928.00          5       2
# 10425   144000.0          Corner house   2266.00          3       2
#
#       Furnishing_quality               State  Garages  rooms
# 162               normal   Baden-Württemberg        9     13
# ...

# %%
df6= df5[(df4.rooms<upper_limit) & (df5.rooms>lower_limit)]
df6
# Out:
# C:\Users\k.belhadj\AppData\Local\Temp\ipykernel_14444\634119643.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df6= df5[(df4.rooms<upper_limit) & (df5.rooms>lower_limit)]
#            Price               Type     Lot  Bathrooms  Floors  \
# 0       498000.0  Multiple dwelling   229.0          1       2
# 1       495000.0  Mid-terrace house   517.0          2       2
# 3       259000.0          Farmhouse   814.0          2       2
# 4       469000.0  Multiple dwelling   244.0          1       2
# 5      1400000.0  Mid-terrace house   860.0          2       3
# ...          ...                ...     ...        ...     ...
# 10541   820000.0  Mid-terrace house  1946.0          2       2
# 10542   399000.0          Farmhouse   160.0          1       2
# 10543   565000.0  Mid-terrace house   660.0          2       2
# 10549   678000.0  Mid-terrace house   377.0          2       2
# 10550   419900.0  Mid-terrace house   501.0          1       2
#
# ...

# %%
dummies = pd.get_dummies(df6.Type)
dummies.head(3)
# Out:
#    Bungalow  Castle  Corner house  Duplex  Farmhouse  Mid-terrace house  \
# 0     False   False         False   False      False              False
# 1     False   False         False   False      False               True
# 3     False   False         False   False       True              False
#
#    Multiple dwelling  Residential property  Single dwelling  Special property  \
# 0               True                 False            False             False
# 1              False                 False            False             False
# 3              False                 False            False             False
#
#    Villa
# 0  False
# 1  False
# 3  False

# %%
dummies1 = pd.get_dummies(df6.State)
dummies1.head(3)
# Out:
#    Baden-Württemberg  Bayern  Berlin  Brandenburg  Bremen  Hamburg  Hessen  \
# 0               True   False   False        False   False    False   False
# 1               True   False   False        False   False    False   False
# 3               True   False   False        False   False    False   False
#
#    Mecklenburg-Vorpommern  Niedersachsen  Nordrhein-Westfalen  \
# 0                   False          False                False
# 1                   False          False                False
# 3                   False          False                False
#
#    Rheinland-Pfalz  Saarland  Sachsen  Sachsen-Anhalt  Schleswig-Holstein  \
# 0            False     False    False           False               False
# 1            False     False    False           False               False
# 3            False     False    False           False               False
#
#    Thüringen
# 0      False
# 1      False
# 3      False

# %%
df7 = pd.concat([df6,dummies, dummies1],axis='columns')
df7.head()
# Out:
#        Price               Type    Lot  Bathrooms  Floors Furnishing_quality  \
# 0   498000.0  Multiple dwelling  229.0          1       2             normal
# 1   495000.0  Mid-terrace house  517.0          2       2              basic
# 3   259000.0          Farmhouse  814.0          2       2              basic
# 4   469000.0  Multiple dwelling  244.0          1       2            refined
# 5  1400000.0  Mid-terrace house  860.0          2       3              basic
#
#                State  Garages  rooms  Bungalow  ...  Hessen  \
# 0  Baden-Württemberg        2      4     False  ...   False
# 1  Baden-Württemberg        7      5     False  ...   False
# 3  Baden-Württemberg        1      6     False  ...   False
# 4  Baden-Württemberg        1      3     False  ...   False
# 5  Baden-Württemberg        2      6     False  ...   False
#
#    Mecklenburg-Vorpommern  Niedersachsen  Nordrhein-Westfalen  \
# 0                   False          False                False
# ...

# %%
df8 = df7.drop(['Type','Furnishing_quality','State'],axis='columns')
df8.head(2)
# Out:
#       Price    Lot  Bathrooms  Floors  Garages  rooms  Bungalow  Castle  \
# 0  498000.0  229.0          1       2        2      4     False   False
# 1  495000.0  517.0          2       2        7      5     False   False
#
#    Corner house  Duplex  ...  Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 0         False   False  ...   False                   False          False
# 1         False   False  ...   False                   False          False
#
#    Nordrhein-Westfalen  Rheinland-Pfalz  Saarland  Sachsen  Sachsen-Anhalt  \
# 0                False            False     False    False           False
# 1                False            False     False    False           False
#
#    Schleswig-Holstein  Thüringen
# 0               False      False
# 1               False      False
#
# [2 rows x 33 columns]

# %%
df8.columns
# Out:
# Index(['Price', 'Lot', 'Bathrooms', 'Floors', 'Garages', 'rooms', 'Bungalow',
#        'Castle', 'Corner house', 'Duplex', 'Farmhouse', 'Mid-terrace house',
#        'Multiple dwelling', 'Residential property', 'Single dwelling',
#        'Special property', 'Villa', 'Baden-Württemberg', 'Bayern', 'Berlin',
#        'Brandenburg', 'Bremen', 'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern',
#        'Niedersachsen', 'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland',
#        'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen'],
#       dtype='object')

# %%
X = df8.drop('Price', axis = 'columns')
y = df8.Price

# %%
X.columns
# Out:
# Index(['Lot', 'Bathrooms', 'Floors', 'Garages', 'rooms', 'Bungalow', 'Castle',
#        'Corner house', 'Duplex', 'Farmhouse', 'Mid-terrace house',
#        'Multiple dwelling', 'Residential property', 'Single dwelling',
#        'Special property', 'Villa', 'Baden-Württemberg', 'Bayern', 'Berlin',
#        'Brandenburg', 'Bremen', 'Hamburg', 'Hessen', 'Mecklenburg-Vorpommern',
#        'Niedersachsen', 'Nordrhein-Westfalen', 'Rheinland-Pfalz', 'Saarland',
#        'Sachsen', 'Sachsen-Anhalt', 'Schleswig-Holstein', 'Thüringen'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)

# %%
from sklearn.preprocessing import MinMaxScaler

norm = MinMaxScaler().fit(X_train)

X_train_norm = norm.transform(X_train)

X_test_norm = norm.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_norm, y_train)
model.score(X_test_norm, y_test)
# Out:
# 0.3187751736732184

# %%
import numpy as np

# %%
x = np.zeros(len(X.columns))
x.shape
# Out:
# (32,)

# %%
def predict_price(State,Type, Lot, Bathrooms, Floors, Garages, rooms):    
    loc_index = np.where(X.columns==State)[0][0]
    type_index = np.where(X.columns==Type)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = Lot
    x[1] = Bathrooms
    x[2] = Floors
    x[3] = Garages
    x[4] = rooms
    if loc_index >= 0:
        x[loc_index] = 1
    if type_index >= 0:
        x[type_index] = 1


    return model.predict([x])[0]

# %%
predict_price('Hessen','Mid-terrace house',300, 3, 3,2,2)
# Out:
# 177248256.0

# %%
import pickle
with open('germany_home_prices_model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
